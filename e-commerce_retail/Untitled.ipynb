# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv("traindata_tjo.csv")
test = pd.read_csv("testdata_tjo.csv")

# %%
train.describe()
# Out:
#           Unnamed: 0      InvoiceNo      StockCode       Quantity  \
# count  284759.000000  284759.000000  284759.000000  284759.000000
# mean   142388.607837    9955.388255    1573.381336      11.865778
# std     82209.067489    5551.350929     843.575095      37.477031
# min         0.000000       0.000000       0.000000   -1350.000000
# 25%     71194.500000    5069.000000     939.000000       2.000000
# 50%    142386.000000   10310.000000    1521.000000       5.000000
# 75%    213585.500000   14657.000000    2106.000000      12.000000
# max    284779.000000   22188.000000    3683.000000    1992.000000
#
#            UnitPrice     CustomerID        Country           Year  \
# count  284759.000000  284759.000000  284759.000000  284759.000000
# mean        3.285949   15288.232017      32.823728    2010.933909
# std        24.125663    1714.354674       6.743801       0.248441
# min         0.000000   12347.000000       0.000000    2010.000000
# ...

# %%
test.describe()
# Out:
#           Unnamed: 0      InvoiceNo      StockCode       Quantity  \
# count  122049.000000  122049.000000  122049.000000  122049.000000
# mean    61024.000000    9940.419692    1572.955788      12.137920
# std     35232.655839    5554.116349     845.106082      54.311646
# min         0.000000       0.000000       0.000000   -9360.000000
# 25%     30512.000000    5018.000000     937.000000       2.000000
# 50%     61024.000000   10311.000000    1523.000000       5.000000
# 75%     91536.000000   14635.000000    2106.000000      12.000000
# max    122048.000000   22189.000000    3683.000000    4800.000000
#
#           CustomerID        Country           Year        Quarter  \
# count  122049.000000  122049.000000  122049.000000  122049.000000
# mean    15286.445256      32.836795    2010.934215       2.849298
# std      1711.887591       6.726816       0.247907       1.125044
# min     12347.000000       0.000000    2010.000000       1.000000
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284759 entries, 0 to 284758
# Data columns (total 12 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 0  284759 non-null  int64
#  1   InvoiceNo   284759 non-null  int64
#  2   StockCode   284759 non-null  int64
#  3   Quantity    284759 non-null  int64
#  4   UnitPrice   284759 non-null  float64
#  5   CustomerID  284759 non-null  float64
#  6   Country     284759 non-null  int64
#  7   Year        284759 non-null  int64
#  8   Quarter     284759 non-null  int64
#  9   Month       284759 non-null  int64
#  10  Day         284759 non-null  int64
#  11  35          284759 non-null  int64
# dtypes: float64(2), int64(10)
# memory usage: 26.1 MB
